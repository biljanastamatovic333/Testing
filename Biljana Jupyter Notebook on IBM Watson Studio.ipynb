# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Biljana</b> <br>
# Data scientist

# %% [markdown]
# <i>I am interested in data science because it is new one and I have knowladge in databese, math, programming.</i>

# %% [markdown]
# <h3>Basic arithmetic operation are ilustrated in the next line:</h3>

# %%
(2+3)*16-75/5
# Out:
# 65.0

# %% [markdown]
# Popular Libraries:
# - dplyr
# - stringer
# - ggplot
# - caret
#
# Name |Color |Age
# -----|-----|-----
# Marko|Blue|13
# Anna|Red|22
# Peter|red|34
# Tom|green|11
#
# Link to [MoDrone](https://modrone.me) SME home page.
